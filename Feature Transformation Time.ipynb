# %% [markdown]
# This is MLP method

# %%
import pandas as pd
import numpy as np
from sklearn.neighbors import KNeighborsClassifier
from sklearn.datasets import make_classification
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import random

# %%
# Data pre-processing
file_path='total_new.csv'
df=pd.read_csv(file_path)
df['Metadata_experiment_type'].value_counts()
df["Metadata_gene"]=df["Metadata_gene"].fillna('empty')
df_fill_empty=df
df_negcon=df_fill_empty[df_fill_empty['Metadata_control_type']=='negcon']
df_rm_negcon=df_fill_empty[df_fill_empty['Metadata_control_type']!='negcon']
df_rm_empty_gene=df_fill_empty[df_fill_empty['Metadata_gene']!='empty']
df_rm_orf=df_rm_empty_gene[df_rm_empty_gene["Metadata_experiment_type"]!='ORF']

# sampling
df_proceed=df_rm_orf[~df_rm_orf['Metadata_pert_type'].isin(['control'])]
# Out:
# /tmp/ipykernel_1478359/275198509.py:3: DtypeWarning: Columns (2,6,7,12,13,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv(file_path)

# %%
# Time
df_test=df_proceed[df_proceed['Metadata_Plate'].isin(
['BR00116996',
 'BR00116997',
 'BR00116998',
 'BR00116999',
 'BR00118045',
 'BR00118046',
 'BR00118047',
 'BR00118048'])]
df_train=df_proceed[df_proceed['Metadata_Plate'].isin(
['BR00116995',
 'BR00117010',
 'BR00117012',
 'BR00117013',
 'BR00117024',
 'BR00117025',
 'BR00117026'])]

# %%
df_negcon=df_negcon.reset_index()
df_test=df_test.reset_index()
df_test=pd.concat([df_test,df_negcon])

# %%
# Train_test pre-process
y_train=df_train['Metadata_gene']
trainX=df_train.drop('Metadata_gene', axis = 1)
testX=df_test.drop('Metadata_gene', axis = 1)
y_test = df_test['Metadata_gene']
trainX=trainX.iloc[:,trainX.columns.get_loc("Cells_AreaShape_BoundingBoxMaximum_Y"):]
testX=testX.iloc[:,testX.columns.get_loc("Cells_AreaShape_BoundingBoxMaximum_Y"):]
trainX=np.array(trainX)
testX=np.array(testX)
trainY=np.array(y_train)
testY=np.array(y_test)

# %%
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import classification_report, recall_score

# Scale the training and test sets using StandardScaler
scaler = StandardScaler()
trainX_scaled = scaler.fit_transform(trainX)
testX_scaled = scaler.transform(testX)
# Train the MLPClassifier model
mlp_clf = MLPClassifier(hidden_layer_sizes=(1280, 630, 300),
                        max_iter=300, activation='relu', verbose=True, tol=1e-8,
                        solver='adam')
mlp_clf.fit(trainX_scaled, trainY)
# Out:
# Iteration 1, loss = 4.67557005
# Iteration 2, loss = 3.56157100
# Iteration 3, loss = 2.72120282
# Iteration 4, loss = 2.14643746
# Iteration 5, loss = 1.67561375
# Iteration 6, loss = 1.32062265
# Iteration 7, loss = 1.06486927
# Iteration 8, loss = 0.83575439
# Iteration 9, loss = 0.62862154
# Iteration 10, loss = 0.47826207
# Iteration 11, loss = 0.34023969
# Iteration 12, loss = 0.24986183
# Iteration 13, loss = 0.16682875
# Iteration 14, loss = 0.10626813
# Iteration 15, loss = 0.07015665
# Iteration 16, loss = 0.05807739
# Iteration 17, loss = 0.04291602
# Iteration 18, loss = 0.05791201
# Iteration 19, loss = 0.03569151
# Iteration 20, loss = 0.09009222
# Iteration 21, loss = 0.05693104
# Iteration 22, loss = 0.04158613
# Iteration 23, loss = 0.06895917
# Iteration 24, loss = 0.04788109
# Iteration 25, loss = 0.07004884
# Iteration 26, loss = 0.04348926
# Iteration 27, loss = 0.04682348
# Iteration 28, loss = 0.02296534
# Iteration 29, loss = 0.01618838
# Iteration 30, loss = 0.00975156
# Iteration 31, loss = 0.00745426
# Iteration 32, loss = 0.00629255
# Iteration 33, loss = 0.00560833
# Iteration 34, loss = 0.00517620
# Iteration 35, loss = 0.00483801
# Iteration 36, loss = 0.00456744
# Iteration 37, loss = 0.00435570
# Iteration 38, loss = 0.00417573
# Iteration 39, loss = 0.00399030
# Iteration 40, loss = 0.00384283
# Iteration 41, loss = 0.00370250
# Iteration 42, loss = 0.00357608
# Iteration 43, loss = 0.00345456
# Iteration 44, loss = 0.00334509
# Iteration 45, loss = 0.00324346
# Iteration 46, loss = 0.00313930
# Iteration 47, loss = 0.00305241
# Iteration 48, loss = 0.00297363
# Iteration 49, loss = 0.00289859
# Iteration 50, loss = 0.00283076
# Iteration 51, loss = 0.00275951
# Iteration 52, loss = 0.00269001
# Iteration 53, loss = 0.00263909
# Iteration 54, loss = 0.00256823
# Iteration 55, loss = 0.00252649
# Iteration 56, loss = 0.00246865
# Iteration 57, loss = 0.00242305
# Iteration 58, loss = 0.00237542
# Iteration 59, loss = 0.00232655
# Iteration 60, loss = 0.00228598
# Iteration 61, loss = 0.00223573
# Iteration 62, loss = 0.00219912
# Iteration 63, loss = 0.00216315
# Iteration 64, loss = 0.00212962
# Iteration 65, loss = 0.00209345
# Iteration 66, loss = 0.00206324
# Iteration 67, loss = 0.00203284
# Iteration 68, loss = 0.00199942
# Iteration 69, loss = 0.00196903
# Iteration 70, loss = 0.00194218
# Iteration 71, loss = 0.00191488
# Iteration 72, loss = 0.00188847
# Iteration 73, loss = 0.00186144
# Iteration 74, loss = 0.00184079
# Iteration 75, loss = 0.00181398
# Iteration 76, loss = 0.00179312
# Iteration 77, loss = 0.00177026
# Iteration 78, loss = 0.00175133
# Iteration 79, loss = 0.00172957
# Iteration 80, loss = 0.00171128
# Iteration 81, loss = 0.00169238
# Iteration 82, loss = 0.00167567
# Iteration 83, loss = 0.00165567
# Iteration 84, loss = 0.00164116
# Iteration 85, loss = 0.00162530
# Iteration 86, loss = 0.00160775
# Iteration 87, loss = 0.00159378
# Iteration 88, loss = 0.00157664
# Iteration 89, loss = 0.00156345
# Iteration 90, loss = 0.00154719
# Iteration 91, loss = 0.00153355
# Iteration 92, loss = 0.00152097
# Iteration 93, loss = 0.00150707
# Iteration 94, loss = 0.00149378
# Iteration 95, loss = 0.00148132
# Iteration 96, loss = 0.00147072
# Iteration 97, loss = 0.00146036
# Iteration 98, loss = 0.00144773
# Iteration 99, loss = 0.00143667
# Iteration 100, loss = 0.00142656
# Iteration 101, loss = 0.00141557
# Iteration 102, loss = 0.00140609
# Iteration 103, loss = 0.00139592
# Iteration 104, loss = 0.00138673
# Iteration 105, loss = 0.00137685
# Iteration 106, loss = 0.00136750
# Iteration 107, loss = 0.00135844
# Iteration 108, loss = 0.00135105
# Iteration 109, loss = 0.00134177
# Iteration 110, loss = 0.00133320
# Iteration 111, loss = 0.00132530
# Iteration 112, loss = 0.00131745
# Iteration 113, loss = 0.00130967
# Iteration 114, loss = 0.00130205
# Iteration 115, loss = 0.00129546
# Iteration 116, loss = 0.00128754
# Iteration 117, loss = 0.00128044
# Iteration 118, loss = 0.00127385
# Iteration 119, loss = 0.00126707
# Iteration 120, loss = 0.00126197
# Iteration 121, loss = 0.00125531
# Iteration 122, loss = 0.00124838
# Iteration 123, loss = 0.00124265
# Iteration 124, loss = 0.00123678
# Iteration 125, loss = 0.00122980
# Iteration 126, loss = 0.00122440
# Iteration 127, loss = 0.00121862
# Iteration 128, loss = 0.00121277
# Iteration 129, loss = 0.00120784
# Iteration 130, loss = 0.00120328
# Iteration 131, loss = 0.00119760
# Iteration 132, loss = 0.00119240
# Iteration 133, loss = 0.00118773
# Iteration 134, loss = 0.00118309
# Iteration 135, loss = 0.00117817
# Iteration 136, loss = 0.00117452
# Iteration 137, loss = 0.00116929
# Iteration 138, loss = 0.00116461
# Iteration 139, loss = 0.00116044
# Iteration 140, loss = 0.00115574
# Iteration 141, loss = 0.00115166
# Iteration 142, loss = 0.00114766
# Iteration 143, loss = 0.00114364
# Iteration 144, loss = 0.00113919
# Iteration 145, loss = 0.00113561
# Iteration 146, loss = 0.00113199
# Iteration 147, loss = 0.00112806
# Iteration 148, loss = 0.00112437
# Iteration 149, loss = 0.00112067
# Iteration 150, loss = 0.00111754
# Iteration 151, loss = 0.00111406
# Iteration 152, loss = 0.00111047
# Iteration 153, loss = 0.00110676
# Iteration 154, loss = 0.00110357
# Iteration 155, loss = 0.00110020
# Iteration 156, loss = 0.00109735
# Iteration 157, loss = 0.00109403
# Iteration 158, loss = 0.00109097
# Iteration 159, loss = 0.00108821
# Iteration 160, loss = 0.00108504
# Iteration 161, loss = 0.00108234
# Iteration 162, loss = 0.00107897
# Iteration 163, loss = 0.00107674
# Iteration 164, loss = 0.00107371
# Iteration 165, loss = 0.00107107
# Iteration 166, loss = 0.00106792
# Iteration 167, loss = 0.00106515
# Iteration 168, loss = 0.00106281
# Iteration 169, loss = 0.00106026
# Iteration 170, loss = 0.00105746
# Iteration 171, loss = 0.00105524
# Iteration 172, loss = 0.00105283
# Iteration 173, loss = 0.00105020
# Iteration 174, loss = 0.00104803
# Iteration 175, loss = 0.00104556
# Iteration 176, loss = 0.00104324
# Iteration 177, loss = 0.00104095
# Iteration 178, loss = 0.00103883
# Iteration 179, loss = 0.00103645
# Iteration 180, loss = 0.00103454
# Iteration 181, loss = 0.00103252
# Iteration 182, loss = 0.00103044
# Iteration 183, loss = 0.00102855
# Iteration 184, loss = 0.00102642
# Iteration 185, loss = 0.00102415
# Iteration 186, loss = 0.00102208
# Iteration 187, loss = 0.00101988
# Iteration 188, loss = 0.00101805
# Iteration 189, loss = 0.00101617
# Iteration 190, loss = 0.00101394
# Iteration 191, loss = 0.00101224
# Iteration 192, loss = 0.00101029
# Iteration 193, loss = 0.00100860
# Iteration 194, loss = 0.00100661
# Iteration 195, loss = 0.00100452
# Iteration 196, loss = 0.00100296
# Iteration 197, loss = 0.00100117
# Iteration 198, loss = 0.00099936
# Iteration 199, loss = 0.00099743
# Iteration 200, loss = 0.00099609
# Iteration 201, loss = 0.00099417
# Iteration 202, loss = 0.00099249
# Iteration 203, loss = 0.00099059
# Iteration 204, loss = 0.00098922
# Iteration 205, loss = 0.00098761
# Iteration 206, loss = 0.00098559
# Iteration 207, loss = 0.00098431
# Iteration 208, loss = 0.00098318
# Iteration 209, loss = 0.00098182
# Iteration 210, loss = 0.00097952
# Iteration 211, loss = 0.00097852
# Iteration 212, loss = 0.00097635
# Iteration 213, loss = 0.00097510
# Iteration 214, loss = 0.00097343
# Iteration 215, loss = 0.00097239
# Iteration 216, loss = 0.00097053
# Iteration 217, loss = 0.00096892
# Iteration 218, loss = 0.00096769
# Iteration 219, loss = 0.00096607
# Iteration 220, loss = 0.00096464
# Iteration 221, loss = 0.00096332
# Iteration 222, loss = 0.00096178
# Iteration 223, loss = 0.00096046
# Iteration 224, loss = 0.00095961
# Iteration 225, loss = 0.00095821
# Iteration 226, loss = 0.00095715
# Iteration 227, loss = 0.00095592
# Iteration 228, loss = 0.00095444
# Iteration 229, loss = 0.00095365
# Iteration 230, loss = 0.00095324
# Iteration 231, loss = 0.00095177
# Iteration 232, loss = 0.00095076
# Iteration 233, loss = 0.00094902
# Iteration 234, loss = 0.00094771
# Iteration 235, loss = 0.00094674
# Iteration 236, loss = 0.00094571
# Iteration 237, loss = 0.00094474
# Iteration 238, loss = 0.00094385
# Iteration 239, loss = 0.00094269
# Iteration 240, loss = 0.00094178
# Iteration 241, loss = 0.00094088
# Iteration 242, loss = 0.00093960
# Iteration 243, loss = 0.00093876
# Iteration 244, loss = 0.00093783
# Iteration 245, loss = 0.00093695
# Iteration 246, loss = 0.00093621
# Iteration 247, loss = 0.00093526
# Iteration 248, loss = 0.00093460
# Iteration 249, loss = 0.00093343
# Iteration 250, loss = 0.00093255
# Iteration 251, loss = 0.00093188
# Iteration 252, loss = 0.00093061
# Iteration 253, loss = 0.00092988
# Iteration 254, loss = 0.00092910
# Iteration 255, loss = 0.00092822
# Iteration 256, loss = 0.00092733
# Iteration 257, loss = 0.00092656
# Iteration 258, loss = 0.00092578
# Iteration 259, loss = 0.00092506
# Iteration 260, loss = 0.00092466
# Iteration 261, loss = 0.00092369
# Iteration 262, loss = 0.00092271
# Iteration 263, loss = 0.00092214
# Iteration 264, loss = 0.00092118
# Iteration 265, loss = 0.00092089
# Iteration 266, loss = 0.00091987
# Iteration 267, loss = 0.00091911
# Iteration 268, loss = 0.00091863
# Iteration 269, loss = 0.00091787
# Iteration 270, loss = 0.00091709
# Iteration 271, loss = 0.00091659
# Iteration 272, loss = 0.00091579
# Iteration 273, loss = 0.00091514
# Iteration 274, loss = 0.00091438
# Iteration 275, loss = 0.00091375
# Iteration 276, loss = 0.00091298
# Iteration 277, loss = 0.00091230
# Iteration 278, loss = 0.00091160
# Iteration 279, loss = 0.00091119
# Iteration 280, loss = 0.00091047
# Iteration 281, loss = 0.00090974
# Iteration 282, loss = 0.00090922
# Iteration 283, loss = 0.00090853
# Iteration 284, loss = 0.00090795
# Iteration 285, loss = 0.00090735
# Iteration 286, loss = 0.00090671
# Iteration 287, loss = 0.00090613
# Iteration 288, loss = 0.00090583
# Iteration 289, loss = 0.00090521
# Iteration 290, loss = 0.00090449
# Iteration 291, loss = 0.00090382
# Iteration 292, loss = 0.00090325
# Iteration 293, loss = 0.00090277
# Iteration 294, loss = 0.00090223
# Iteration 295, loss = 0.00090166
# Iteration 296, loss = 0.00090136
# Iteration 297, loss = 0.00090105
# Iteration 298, loss = 0.00090042
# Iteration 299, loss = 0.00089980
# Iteration 300, loss = 0.00089919
# /home/yuchen.yang@insilico.ai/.local/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(
# MLPClassifier(hidden_layer_sizes=(1280, 630, 300), max_iter=300, tol=1e-08,
#               verbose=True)

# %%
df_proceed=df_proceed.reset_index()
df_negcon=df_negcon.reset_index()
df_proceed=pd.concat([df_proceed,df_negcon])
##### Feature Transformation Seen 
import torch
import torch.nn as nn
relu = nn.ReLU(inplace=True)
original_seen=df_proceed.iloc[:,df_proceed.columns.get_loc("Cells_AreaShape_BoundingBoxMaximum_Y"):-1]
sc=StandardScaler()
scaler = sc.fit(original_seen)
original_seen_scaled = scaler.transform(original_seen)
layer_1=np.array(relu(torch.from_numpy(np.dot(original_seen_scaled,mlp_clf.coefs_[0])+mlp_clf.intercepts_[0])))
layer_2=np.array(relu(torch.from_numpy(np.dot(layer_1,mlp_clf.coefs_[1])+mlp_clf.intercepts_[1])))
layer_3=np.array(relu(torch.from_numpy(np.dot(layer_2,mlp_clf.coefs_[2])+mlp_clf.intercepts_[2])))
transformen_seen=df_proceed.iloc[:,0:df_proceed.columns.get_loc("Cells_AreaShape_BoundingBoxMaximum_Y")]
feature=pd.DataFrame(layer_3)
feature.index=transformen_seen.index
feature_new =pd.concat([transformen_seen,feature,df_proceed['Metadata_experiment_type']], axis=1)

# %%
feature_new.to_csv('MLP_short_new.csv')
df_proceed.to_csv('MLP_short_old.csv')

# %% [markdown]
# This is SLPP Method

# %%
# Data pre-processing
file_path='total_new.csv'
df=pd.read_csv(file_path)
df['Metadata_experiment_type'].value_counts()
df["Metadata_gene"]=df["Metadata_gene"].fillna('empty')
df_fill_empty=df
df_negcon=df_fill_empty[df_fill_empty['Metadata_control_type']=='negcon']
df_rm_negcon=df_fill_empty[df_fill_empty['Metadata_control_type']!='negcon']
df_rm_empty_gene=df_fill_empty[df_fill_empty['Metadata_gene']!='empty']
df_rm_orf=df_rm_empty_gene[df_rm_empty_gene["Metadata_experiment_type"]!='ORF']

# sampling
df_proceed=df_rm_orf[~df_rm_orf['Metadata_pert_type'].isin(['control'])]
# Time
df_test=df_proceed[df_proceed['Metadata_Plate'].isin(
['BR00116996',
 'BR00116997',
 'BR00116998',
 'BR00116999',
 'BR00118045',
 'BR00118046',
 'BR00118047',
 'BR00118048'])]
df_train=df_proceed[df_proceed['Metadata_Plate'].isin(
['BR00116995',
 'BR00117010',
 'BR00117012',
 'BR00117013',
 'BR00117024',
 'BR00117025',
 'BR00117026'])]
# Train_test pre-process
df_negcon=df_negcon.reset_index()
df_test=df_test.reset_index()
df_test=pd.concat([df_test,df_negcon])
y_train=df_train['Metadata_gene']
trainX=df_train.drop('Metadata_gene', axis = 1)
df_proceed=df_proceed.reset_index()
df_negcon=df_negcon.reset_index()
df_proceed=pd.concat([df_proceed,df_negcon])
df_proceed=df_proceed.iloc[:,:-1]
testX=df_proceed.drop('Metadata_gene', axis = 1)
y_test = df_test['Metadata_gene']
trainX=trainX.iloc[:,trainX.columns.get_loc("Cells_AreaShape_BoundingBoxMaximum_Y"):]
testX=testX.iloc[:,testX.columns.get_loc("Cells_AreaShape_BoundingBoxMaximum_Y"):]
trainX=np.array(trainX)
testX=np.array(testX)
trainY=np.array(y_train)
testY=np.array(y_test)
# Out:
# /tmp/ipykernel_1478359/3618204328.py:3: DtypeWarning: Columns (2,6,7,12,13,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv(file_path)

# %%
X_train = trainX
y_train = y_train.reset_index()
y_train=y_train['Metadata_gene'].tolist()
n_components=300
sigma=1.0

# %%
## code from: github.com/tanyapole/reproduce-OSLPP/blob/main/OSLPP.py
import scipy 

def get_l2_norm(features:np.ndarray): return np.sqrt(np.square(features).sum(axis=1)).reshape((-1,1))

def get_l2_normalized(features:np.ndarray): return features / get_l2_norm(features)

def get_PCA(features, dim):
    result = PCA(n_components=dim).fit_transform(features)
    assert len(features) == len(result)
    return result

def get_W(labels,):
    W = (labels.reshape(-1,1) == labels).astype(np.int32)
    negative_one_idxs = np.where(labels == -1)[0]
    W[:,negative_one_idxs] = 0
    W[negative_one_idxs,:] = 0
    return W

def get_D(W): return np.eye(len(W), dtype=np.int32) * W.sum(axis=1)

def fix_numerical_assymetry(M): return (M + M.transpose()) * 0.5

def get_projection_matrix(features, labels, proj_dim):
    N, d = features.shape
    X = features.transpose()
    
    W = get_W(labels)
    D = get_D(W)
    L = D - W

    A = fix_numerical_assymetry(np.matmul(np.matmul(X, D), X.transpose()))
    B = fix_numerical_assymetry(np.matmul(np.matmul(X, L), X.transpose()) + np.eye(d))
    assert (A.transpose() == A).all() and (B.transpose() == B).all()

    w, v = scipy.linalg.eigh(A, B)
    assert w[0] < w[-1]
    w, v = w[-proj_dim:], v[:, -proj_dim:]
    assert np.abs(np.matmul(A, v) - w * np.matmul(B, v)).max() < 1e-5

    w = np.flip(w)
    v = np.flip(v, axis=1)

    for i in range(v.shape[1]):
        if v[0,i] < 0:
            v[:,i] *= -1
    return v

def project_features(P, features):
    # P: pca_dim x proj_dim
    # features: N x pca_dim
    # result: N x proj_dim
    return np.matmul(P.transpose(), features.transpose()).transpose()

y_train_array = np.array(y_train)
P = get_projection_matrix(trainX, y_train_array, n_components)
# Out:
# /tmp/ipykernel_1478359/1419865204.py:15: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   negative_one_idxs = np.where(labels == -1)[0]

# %%
## transformed seen_test_data
transformed_data = np.dot(testX, P)
new_feature=pd.DataFrame(transformed_data)
testX1=df_proceed.iloc[:,:df_proceed.columns.get_loc("Cells_AreaShape_BoundingBoxMaximum_Y")]
testX1=testX1.reset_index()
dfnew =pd.concat([testX1,new_feature],axis=1)

# %%
dfnew.iloc[:,1:].to_csv('SLPP_short_new.csv')          # After feature transformation
df_proceed.to_csv('SLPP_short_old.csv')                  # Before feature transformation
